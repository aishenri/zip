# %% [markdown]
# #### An de grâce 2018, vendredi 6 juillet 10h45

# %%
# %display latex

# %% [markdown]
# Quadrature : Cercle : 4, Carré : 4

# %%
r=2/sqrt(n(pi));cercle=n(pi)*(r^2);carre=2*2;show("Rayon : r = ",r)
show("Cercle =",round(cercle)," Carre =",carre)
# Out:
# 'Rayon : r = ' 1.12837916709551
# 'Cercle =' 4 ' Carre =' 4

# %%
p3=plot(circle((0,0),r,color="red",fill=True,alpha=0.2,)\
+polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",
alpha=0.2,thickness=1,axes=True));
p2= circle((0,0),r,color="red",fill=True,alpha=0.2,fontsize=6)  
p1=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2);
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",
gridlinesstyle=dict(color="lightgrey",linestyle="-",alpha=1))
# Out:
# Graphics Array of size 1 x 3
